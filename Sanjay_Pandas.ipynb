# %% [markdown]
# <a href="https://colab.research.google.com/github/delhisanjay/MachineLearning/blob/main/Sanjay_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Pandas
import pandas as pd

# %%
data = pd.Series([10,20,30,40,50,60,70])
display(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
## int8 = it can take 8 bit of value (-128 to +127)
data = pd.Series([10,20,30,40,50,60,70], index = [] dtype = 'int8')

# %%
# Collection of series
data_series = {
    'Column' : pd.Series([10,20,30,40,50,60,70]
}

# %%
movies_df = pd.read_csv('https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/movies.csv', sep = ',', header = 0)
display(movies_df)
# Out:
#                                   Film    Genre  ... Worldwide Gross  Year
# 0           Zack and Miri Make a Porno  Romance  ...         $41.94   2008
# 1                      Youth in Revolt   Comedy  ...         $19.62   2010
# 2   You Will Meet a Tall Dark Stranger   Comedy  ...         $26.66   2010
# 3                         When in Rome   Comedy  ...         $43.04   2010
# 4                What Happens in Vegas   Comedy  ...        $219.37   2008
# ..                                 ...      ...  ...             ...   ...
# 72                 Across the Universe  romance  ...         $29.37   2007
# 73                       A Serious Man    Drama  ...         $30.68   2009
# 74                  A Dangerous Method    Drama  ...          $8.97   2011
# 75                          27 Dresses   Comedy  ...        $160.31   2008
# 76                (500) Days of Summer   comedy  ...         $60.72   2009
#
# [77 rows x 8 columns]

# %%
movies_df.tail()
# Out:
#                     Film    Genre  ... Worldwide Gross  Year
# 72   Across the Universe  romance  ...         $29.37   2007
# 73         A Serious Man    Drama  ...         $30.68   2009
# 74    A Dangerous Method    Drama  ...          $8.97   2011
# 75            27 Dresses   Comedy  ...        $160.31   2008
# 76  (500) Days of Summer   comedy  ...         $60.72   2009
#
# [5 rows x 8 columns]

# %%
movies_df.head(8)
# Out:
#                                  Film      Genre  ... Worldwide Gross  Year
# 0          Zack and Miri Make a Porno    Romance  ...         $41.94   2008
# 1                     Youth in Revolt     Comedy  ...         $19.62   2010
# 2  You Will Meet a Tall Dark Stranger     Comedy  ...         $26.66   2010
# 3                        When in Rome     Comedy  ...         $43.04   2010
# 4               What Happens in Vegas     Comedy  ...        $219.37   2008
# 5                 Water For Elephants      Drama  ...        $117.09   2011
# 6                              WALL-E  Animation  ...        $521.28   2008
# 7                            Waitress    Romance  ...         $22.18   2007
#
# [8 rows x 8 columns]

# %%
# Read excel file
stock_data = pd.read_excel('https://github.com/ammishra08/MachineLearning/blob/master/Datasets/data_akbilgic.xlsx?raw=true', header=1)
display(stock_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#           date       ISE     ISE.1  ...   BOVESPA        EU        EM
# 0   2009-01-05  0.035754  0.038376  ...  0.031190  0.012698  0.028524
# 1   2009-01-06  0.025426  0.031813  ...  0.018920  0.011341  0.008773
# 2   2009-01-07 -0.028862 -0.026353  ... -0.035899 -0.017073 -0.020015
# 3   2009-01-08 -0.062208 -0.084716  ...  0.028283 -0.005561 -0.019424
# 4   2009-01-09  0.009860  0.009658  ... -0.009764 -0.010989 -0.007802
# ..         ...       ...       ...  ...       ...       ...       ...
# 531 2011-02-16  0.008599  0.013400  ...  0.018371  0.006975  0.003039
# 532 2011-02-17  0.009310  0.015977  ...  0.001686 -0.000581  0.001039
# 533 2011-02-18  0.000191 -0.001653  ...  0.005628  0.000572  0.006938
# 534 2011-02-21 -0.013069 -0.013706  ... -0.011942 -0.012615 -0.000958
# ...

# %%
movies_df.shape
# Out:
# (77, 8)

# %%
movies_df.columns
# Out:
# Index(['Film', 'Genre', 'Lead Studio', 'Audience score %', 'Profitability',
#        'Rotten Tomatoes %', 'Worldwide Gross', 'Year'],
#       dtype='object')

# %%
len(movies_df.columns)
# Out:
# 8

# %%
print(movies_df.shape[1])
# Out:
# 8

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               77 non-null     object
#  1   Genre              77 non-null     object
#  2   Lead Studio        77 non-null     object
#  3   Audience score %   77 non-null     int64
#  4   Profitability      77 non-null     float64
#  5   Rotten Tomatoes %  77 non-null     int64
#  6   Worldwide Gross    77 non-null     object
#  7   Year               77 non-null     int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 4.9+ KB

# %% [markdown]
# Typecasting the columns Data Types

# %%
# selecting one column
movies_df['Rotten Tomatoes %']
# Out:
# 0     64
# 1     68
# 2     43
# 3     15
# 4     28
#       ..
# 72    54
# 73    89
# 74    79
# 75    40
# 76    87
# Name: Rotten Tomatoes %, Length: 77, dtype: int64

# %% [markdown]
# loc and iloc are used for slicing based on column name and index values

# %% [markdown]
# # Filter Data

# %%
# Filter Data
movies_df.filter(like = 'a')
# Out:
#               Lead Studio  Profitability  Rotten Tomatoes %  Year
# 0   The Weinstein Company       1.747542                 64  2008
# 1   The Weinstein Company       1.090000                 68  2010
# 2             Independent       1.211818                 43  2010
# 3                  Disney       0.000000                 15  2010
# 4                     Fox       6.267647                 28  2008
# ..                    ...            ...                ...   ...
# 72            Independent       0.652603                 54  2007
# 73              Universal       4.382857                 89  2009
# 74            Independent       0.448645                 79  2011
# 75                    Fox       5.343622                 40  2008
# 76                    Fox       8.096000                 87  2009
#
# [77 rows x 4 columns]

# %%
movies_df[(movies_df.Genre == 'Romance') & (movies_df['Audience score %'] > 80)]
# Out:
#                Film    Genre  ... Worldwide Gross  Year
# 12         Twilight  Romance  ...        $376.66   2008
# 31  P.S. I Love You  Romance  ...        $153.09   2007
#
# [2 rows x 8 columns]

# %%
# axis = 0 row wise and axis =1 column wise
movies_df.drop(2).head()
# Out:
#                          Film    Genre  ... Worldwide Gross  Year
# 0  Zack and Miri Make a Porno  Romance  ...         $41.94   2008
# 1             Youth in Revolt   Comedy  ...         $19.62   2010
# 3                When in Rome   Comedy  ...         $43.04   2010
# 4       What Happens in Vegas   Comedy  ...        $219.37   2008
# 5         Water For Elephants    Drama  ...        $117.09   2011
#
# [5 rows x 8 columns]

# %% [markdown]
# Frequency Distribution

# %%
movies_df['Genre'].value_counts()
# Out:
# Comedy       41
# Romance      13
# Drama        13
# Animation     4
# Fantasy       1
# Romence       1
# Comdy         1
# Action        1
# romance       1
# comedy        1
# Name: Genre, dtype: int64

# %%
movies_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# Length: 77, dtype: bool

# %%
movies_df.isnull()
# Out:
#      Film  Genre  Lead Studio  ...  Rotten Tomatoes %  Worldwide Gross   Year
# 0   False  False        False  ...              False            False  False
# 1   False  False        False  ...              False            False  False
# 2   False  False        False  ...              False            False  False
# 3   False  False        False  ...              False            False  False
# 4   False  False        False  ...              False            False  False
# ..    ...    ...          ...  ...                ...              ...    ...
# 72  False  False        False  ...              False            False  False
# 73  False  False        False  ...              False            False  False
# 74  False  False        False  ...              False            False  False
# 75  False  False        False  ...              False            False  False
# 76  False  False        False  ...              False            False  False
#
# [77 rows x 8 columns]

# %%
duplicate = movies_df[movies_df.duplicated()]
duplicate
# Out:
#                  Film      Genre  ... Worldwide Gross  Year
# 46         Mamma Mia!     Comedy  ...        $609.47   2008
# 65  Gnomeo and Juliet  Animation  ...        $193.97   2011
#
# [2 rows x 8 columns]

# %%
movies_df.plot(figsize=(12,7))

# %%
stock_data
# Out:
#           date       ISE     ISE.1  ...   BOVESPA        EU        EM
# 0   2009-01-05  0.035754  0.038376  ...  0.031190  0.012698  0.028524
# 1   2009-01-06  0.025426  0.031813  ...  0.018920  0.011341  0.008773
# 2   2009-01-07 -0.028862 -0.026353  ... -0.035899 -0.017073 -0.020015
# 3   2009-01-08 -0.062208 -0.084716  ...  0.028283 -0.005561 -0.019424
# 4   2009-01-09  0.009860  0.009658  ... -0.009764 -0.010989 -0.007802
# ..         ...       ...       ...  ...       ...       ...       ...
# 531 2011-02-16  0.008599  0.013400  ...  0.018371  0.006975  0.003039
# 532 2011-02-17  0.009310  0.015977  ...  0.001686 -0.000581  0.001039
# 533 2011-02-18  0.000191 -0.001653  ...  0.005628  0.000572  0.006938
# 534 2011-02-21 -0.013069 -0.013706  ... -0.011942 -0.012615 -0.000958
# 535 2011-02-22 -0.007246 -0.019442  ... -0.012252 -0.005465 -0.014297
#
# [536 rows x 10 columns]

# %%
stock_data['ISE'].plot(color='violet')
